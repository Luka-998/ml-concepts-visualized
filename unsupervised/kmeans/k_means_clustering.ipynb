# %% [markdown]
# ## K means

# %% [markdown]
# #### Unsupervised machine learning algorithm used for sorting data points into K cluster
#
# ### **Goal:**
#
# ### 1) Minimize the total variations between K clusters using squarred Euclidean distance
#
# ### 2) K clusters are predefined parameter
