# %% [markdown]
# ### Sofmtax - Used in multiple classification task
#
# - Extension of Binary Cross entropy (2 class)

# %% [markdown]
# ### LogisticRegression BinaryCrossEtropy: (2 possible output values 0/1)
#
# P ( y = 1 | x) = y_hat
#
# P (y = 0 | x) = 1 - y_hat
#
# ...
#
# Loss = - [ yi*log*( y_hat ) + ( 1 - y )*log*( 1 - y_hat)]
#
# Z[1] = X[0] @ W + b
#
# A[1] = g(Z[1])
#
# while **g**: (activation)
#
# g = 1 / (1 + e ^-z)

# %% [markdown]
# If A[1] P( y = 1 | X) = 0.7
#
# A[1] P ( **y = 0** | x ) = > 0.3
#
# If there are more than 2 classes?

# %% [markdown]
# z1 = x @ w1 + b1
# z2 = x @ w2 + b2
# z3 = x @ w3 + b3
# z4 = x @ w4 + b4
#
# 4 possible outputs
#
# **a1 = e^z1 / e^z1 + e^z2 + e^z3 + e^z4** P ( y  = 1 | x )
#
# **a2 = e^z2 / e^z1 + e^z2 + e^z3 + e^z4** P ( y = 2 | x )
# ...
# for P(a_)<=1
#
# P(a1) + P(a2) + P(a3) + P(a4) <= 1

# %% [markdown]
# ### Loss function:
#
# J = - logAi
#
# Softmax loss is computed by taking the negative log of predicting positive class
#
# if Ai is close to 1 , the loss is very small, but when Ai is close to 0 (which means we have high error in prediction) the Loss is high!

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import Model,Sequential
from keras.layers import Dense

# %%
X,y= make_classification(n_classes=4,n_features=13,n_samples=10000,n_informative=9)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
np.unique(y)
# 4 class
# Out:
# array([0, 1, 2, 3])

# %%
tf.random.set_seed(41)
model = Sequential(
    [
        Dense(2,activation='relu', name='L1'),
        Dense(4,activation='linear', name='L2')
    ]
)

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(0.1))

model.fit(X_train,y_train,epochs=20)
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0227
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 1.0239
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0248
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0284
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0304
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0280
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 1.0278
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0298
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0325
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0267
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0291
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0269
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0335
# Epoch 14/20
# ...
